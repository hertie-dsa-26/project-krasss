# %% [markdown]
# # Exploratory Data Analysis: Bivariate

# %% [markdown]
# ## 1. Import packages

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load data

# %% [markdown]
# Load the merged data set `noaa_cdc_uscensus.csv` and get familiar with it.

# %%
df = pd.read_csv("data/noaa_cdc_uscensus.csv")

# %% [markdown]
# ## 3. Wrangle and inspect data

# %% [markdown]
# ### 3.1. Pivot to wider format

# %%
measure_specific = ['measureid_c', 'measure_c', 'data_value_c', 'low_confidence_limit_c',
                    'high_confidence_limit_c', 'category_c', 'categoryid_c', 'short_question_text_c']
index_cols = [c for c in df.columns if c not in measure_specific]

df_pivot = df.pivot(
    index=index_cols,
    columns='measureid_c',
    values=['data_value_c', 'low_confidence_limit_c', 'high_confidence_limit_c']
).reset_index()

df_pivot.columns = [''.join(col).strip('') if isinstance(col, tuple) else col for col in df_pivot.columns]

print(df_pivot.shape)
df_pivot.head()
# Out:
# (1818, 70)
#    year stateabbr_c statedesc_c locationname_c  locationid_c  \
# 0  2014          AK      Alaska      Anchorage        203000
# 1  2014          AL     Alabama     Birmingham        107000
# 2  2014          AL     Alabama     Huntsville        137000
# 3  2014          AL     Alabama         Mobile        150000
# 4  2014          AL     Alabama     Montgomery        151000
#
#   totalpopulation_c                    geolocation_c  \
# 0           291,826   (61.149868731, -149.111113424)
# 1           212,237  (33.5275663773, -86.7988174678)
# 2           180,105  (34.6989692671, -86.6387042882)
# 3           195,111  (30.6776248648, -88.1184482714)
# 4           205,764  (32.3472645333, -86.2677059552)
#
#                sca_release_id_c                      msa_c  msa_code  ...  \
# 0  2014_500_Cities_2016_release   Anchorage, AK Metro Area     112.0  ...
# 1  2014_500_Cities_2016_release  Birmingham, AL Metro Area     136.0  ...
# 2  2014_500_Cities_2016_release  Huntsville, AL Metro Area     259.0  ...
# 3  2014_500_Cities_2016_release      Mobile, AL Metro Area     333.0  ...
# 4  2014_500_Cities_2016_release  Montgomery, AL Metro Area     337.0  ...
#
#   low_confidence_limit_cPHLTH low_confidence_limit_cSTROKE  \
# 0                         9.8                          2.6
# 1                        18.0                          5.0
# 2                        13.7                          3.1
# 3                        16.1                          4.0
# 4                        16.0                          4.0
#
#   high_confidence_limit_cCASTHMA  high_confidence_limit_cCHD  \
# 0                            8.6                         5.1
# 1                           11.5                         7.7
# 2                            9.7                         6.8
# 3                           10.8                         7.7
# 4                           10.9                         7.3
#
#    high_confidence_limit_cCOPD  high_confidence_limit_cLPA  \
# 0                          5.1                        19.5
# 1                          9.6                        32.1
# 2                          7.7                        25.3
# 3                          8.8                        27.8
# 4                          8.8                        28.3
#
#   high_confidence_limit_cMHLTH  high_confidence_limit_cOBESITY  \
# 0                          9.5                            27.9
# 1                         17.2                            39.1
# 2                         14.2                            32.2
# 3                         16.0                            37.8
# 4                         15.7                            37.1
#
#    high_confidence_limit_cPHLTH  high_confidence_limit_cSTROKE
# 0                          10.1                            2.6
# 1                          18.5                            5.1
# 2                          14.2                            3.2
# 3                          16.5                            4.1
# 4                          16.4                            4.1
#
# [5 rows x 70 columns]

# %% [markdown]
# ## 3.2. Inspect pivoted data set

# %%
df_pivot.shape
# Out:
# (1818, 70)

# %%
df_pivot.head
# Out:
# <bound method NDFrame.head of       year stateabbr_c    statedesc_c locationname_c  locationid_c  \
# 0     2014          AK         Alaska      Anchorage        203000
# 1     2014          AL        Alabama     Birmingham        107000
# 2     2014          AL        Alabama     Huntsville        137000
# 3     2014          AL        Alabama         Mobile        150000
# 4     2014          AL        Alabama     Montgomery        151000
# ...    ...         ...            ...            ...           ...
# 1813  2023          WI      Wisconsin        Madison       5548000
# 1814  2023          WI      Wisconsin      Milwaukee       5553000
# 1815  2023          WI      Wisconsin         Racine       5566000
# 1816  2023          WV  West Virginia     Charleston       5414600
# 1817  2023          WY        Wyoming       Cheyenne       5613900
#
#      totalpopulation_c                    geolocation_c  \
# 0              291,826   (61.149868731, -149.111113424)
# 1              212,237  (33.5275663773, -86.7988174678)
# 2              180,105  (34.6989692671, -86.6387042882)
# 3              195,111  (30.6776248648, -88.1184482714)
# 4              205,764  (32.3472645333, -86.2677059552)
# ...                ...                              ...
# 1813           269,840         (-89.4298563 43.0878147)
# 1814           577,222         (-87.9666952 43.0633484)
# 1815            77,816          (-87.814224 42.7255685)
# 1816            48,864          (-81.632324 38.3486917)
# 1817            65,132        (-104.7907492 41.1352586)
#
#                   sca_release_id_c                                 msa_c  \
# 0     2014_500_Cities_2016_release              Anchorage, AK Metro Area
# 1     2014_500_Cities_2016_release             Birmingham, AL Metro Area
# 2     2014_500_Cities_2016_release             Huntsville, AL Metro Area
# 3     2014_500_Cities_2016_release                 Mobile, AL Metro Area
# 4     2014_500_Cities_2016_release             Montgomery, AL Metro Area
# ...                            ...                                   ...
# 1813      2023_PLACES_2025_release                Madison, WI Metro Area
# 1814      2023_PLACES_2025_release     Milwaukee-Waukesha, WI Metro Area
# 1815      2023_PLACES_2025_release  Racine-Mount Pleasant, WI Metro Area
# 1816      2023_PLACES_2025_release             Charleston, WV Metro Area
# 1817      2023_PLACES_2025_release               Cheyenne, WY Metro Area
#
#       msa_code  ... low_confidence_limit_cPHLTH low_confidence_limit_cSTROKE  \
# 0        112.0  ...                         9.8                          2.6
# 1        136.0  ...                        18.0                          5.0
# 2        259.0  ...                        13.7                          3.1
# 3        333.0  ...                        16.1                          4.0
# 4        337.0  ...                        16.0                          4.0
# ...        ...  ...                         ...                          ...
# 1813     316.0  ...                         9.8                          2.3
# 1814     329.0  ...                        14.0                          4.1
# 1815     383.0  ...                        12.7                          3.3
# 1816     161.0  ...                        12.8                          3.0
# 1817     166.0  ...                        11.5                          2.5
#
#      high_confidence_limit_cCASTHMA  high_confidence_limit_cCHD  \
# 0                               8.6                         5.1
# 1                              11.5                         7.7
# 2                               9.7                         6.8
# 3                              10.8                         7.7
# 4                              10.9                         7.3
# ...                             ...                         ...
# 1813                           11.2                         5.2
# 1814                           13.9                         7.1
# 1815                           13.5                         6.7
# 1816                           13.6                         7.0
# 1817                           11.5                         5.5
#
#       high_confidence_limit_cCOPD  high_confidence_limit_cLPA  \
# 0                             5.1                        19.5
# 1                             9.6                        32.1
# 2                             7.7                        25.3
# 3                             8.8                        27.8
# 4                             8.8                        28.3
# ...                           ...                         ...
# 1813                          5.0                        25.0
# 1814                          8.3                        36.1
# 1815                          7.4                        39.8
# 1816                          8.4                        32.7
# 1817                          6.5                        30.2
#
#      high_confidence_limit_cMHLTH  high_confidence_limit_cOBESITY  \
# 0                             9.5                            27.9
# 1                            17.2                            39.1
# 2                            14.2                            32.2
# 3                            16.0                            37.8
# 4                            15.7                            37.1
# ...                           ...                             ...
# 1813                         16.8                            38.4
# 1814                         20.4                            46.0
# 1815                         19.5                            51.3
# 1816                         24.2                            44.9
# 1817                         18.7                            38.4
#
#       high_confidence_limit_cPHLTH  high_confidence_limit_cSTROKE
# 0                             10.1                            2.6
# 1                             18.5                            5.1
# 2                             14.2                            3.2
# 3                             16.5                            4.1
# 4                             16.4                            4.1
# ...                            ...                            ...
# 1813                          12.2                            2.7
# 1814                          16.9                            4.7
# 1815                          15.7                            3.9
# 1816                          16.2                            3.6
# 1817                          14.2                            2.9
#
# [1818 rows x 70 columns]>

# %%
df_pivot.dtypes
# Out:
# year                                int64
# stateabbr_c                           str
# statedesc_c                           str
# locationname_c                        str
# locationid_c                        int64
#                                    ...
# high_confidence_limit_cLPA        float64
# high_confidence_limit_cMHLTH      float64
# high_confidence_limit_cOBESITY    float64
# high_confidence_limit_cPHLTH      float64
# high_confidence_limit_cSTROKE     float64
# Length: 70, dtype: object

# %%
df.isnull().sum()
# Out:
# year                             0
# stateabbr_c                      0
# statedesc_c                      0
# locationname_c                   0
# category_c                       0
# locationid_c                     0
# measure_c                        0
# data_value_c                     0
# low_confidence_limit_c           0
# high_confidence_limit_c          0
# totalpopulation_c                0
# geolocation_c                    0
# categoryid_c                     0
# measureid_c                      0
# short_question_text_c            0
# sca_release_id_c                 0
# msa_c                            0
# msa_code                         0
# state_c                          0
# short_name_c                     0
# source_dataset_c                 0
# year_coverage_c                  0
# latitude_n                     216
# longitude_n                    216
# name_n                         216
# cldd_n                        1096
# dt00_n                        1016
# dt32_n                        1016
# dx32_n                        1008
# dx70_n                        1008
# dx90_n                        1008
# emnt_n                        1016
# emxt_n                        1008
# htdd_n                        1080
# prcp_n                         616
# tavg_n                        1080
# tmax_n                        1008
# tmin_n                        1016
# tsun_n                       14520
# msa_n                          216
# msa_u                         2352
# total_population_u            2352
# median_age_u                  2352
# pct_male_u                    2352
# pct_female_u                  2352
# cbsa_code_u                   2352
# median_household_income_u     2352
# pct_bachelors_plus_u          2352
# pct_graduate_degree_u         2352
# pct_less_than_hs_u            2352
# pct_white_u                   2352
# pct_black_u                   2352
# pct_hispanic_u                2352
# pct_asian_u                   2352
# dtype: int64

# %% [markdown]
# ## 3.3. Drop unnecessary columns

# %%
df_pivot.columns
# Out:
# Index(['year', 'stateabbr_c', 'statedesc_c', 'locationname_c', 'locationid_c',
#        'totalpopulation_c', 'geolocation_c', 'sca_release_id_c', 'msa_c',
#        'msa_code', 'state_c', 'short_name_c', 'source_dataset_c',
#        'year_coverage_c', 'latitude_n', 'longitude_n', 'name_n', 'cldd_n',
#        'dt00_n', 'dt32_n', 'dx32_n', 'dx70_n', 'dx90_n', 'emnt_n', 'emxt_n',
#        'htdd_n', 'prcp_n', 'tavg_n', 'tmax_n', 'tmin_n', 'tsun_n', 'msa_n',
#        'msa_u', 'total_population_u', 'median_age_u', 'pct_male_u',
#        'pct_female_u', 'cbsa_code_u', 'median_household_income_u',
#        'pct_bachelors_plus_u', 'pct_graduate_degree_u', 'pct_less_than_hs_u',
#        'pct_white_u', 'pct_black_u', 'pct_hispanic_u', 'pct_asian_u',
#        'data_value_cCASTHMA', 'data_value_cCHD', 'data_value_cCOPD',
#        'data_value_cLPA', 'data_value_cMHLTH', 'data_value_cOBESITY',
#        'data_value_cPHLTH', 'data_value_cSTROKE',
#        'low_confidence_limit_cCASTHMA', 'low_confidence_limit_cCHD',
#        'low_confidence_limit_cCOPD', 'low_confidence_limit_cLPA',
#        'low_confidence_limit_cMHLTH', 'low_confidence_limit_cOBESITY',
#        'low_confidence_limit_cPHLTH', 'low_confidence_limit_cSTROKE',
#        'high_confidence_limit_cCASTHMA', 'high_confidence_limit_cCHD',
#        'high_confidence_limit_cCOPD', 'high_confidence_limit_cLPA',
#        'high_confidence_limit_cMHLTH', 'high_confidence_limit_cOBESITY',
#        'high_confidence_limit_cPHLTH', 'high_confidence_limit_cSTROKE'],
#       dtype='str')
